# %%
# %matplotlib inline

# %%
from skimage import io
io.imread('./small.jpg', plugin='matplotlib')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-10-0bd712b7918c> in <module>()
#       1 from skimage import io
# ----> 2 io.imread('./small.jpg', plugin='matplotlib')
#
# /home/morten/.virtualenvs/Theano/local/lib/python2.7/site-packages/skimage/io/_io.pyc in imread(fname, as_grey, plugin, flatten, **plugin_args)
#      98
#      99     with file_or_url_context(fname) as fname:
# --> 100         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#     101
#     102     if as_grey and getattr(img, 'ndim', 0) >= 3:
#
# /home/morten/.virtualenvs/Theano/local/lib/python2.7/site-packages/skimage/io/manage_plugins.pyc in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# /home/morten/.virtualenvs/Theano/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in imread(*args, **kwargs)
#    2213 @docstring.copy_dedent(_imread)
#    2214 def imread(*args, **kwargs):
# -> 2215     return _imread(*args, **kwargs)
#    2216
#    2217
#
# /home/morten/.virtualenvs/Theano/local/lib/python2.7/site-packages/matplotlib/image.pyc in imread(fname, format)
#    1252
#    1253     if ext not in handlers:
# -> 1254         im = pilread(fname)
#    1255         if im is None:
#    1256             raise ValueError('Only know how to handle extensions: %s; '
#
# /home/morten/.virtualenvs/Theano/local/lib/python2.7/site-packages/matplotlib/image.pyc in pilread(fname)
#    1231         if cbook.is_string_like(fname):
#    1232             # force close the file after reading the image
# -> 1233             with open(fname, "rb") as fh:
#    1234                 image = Image.open(fh)
#    1235                 return pil_to_array(image)
#
# IOError: [Errno 2] No such file or directory: './small.jpg'

# %%
import os 
import numpy as np
import skimage
import matplotlib.pyplot as plt

# %%
camera = skimage.io.imread(os.path.join(skimage.data_dir, 'camera.png'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-60e8afd4327b> in <module>()
# ----> 1 camera = skimage.io.imread(os.path.join(skimage.data_dir, 'camera.png'))
#
# AttributeError: 'module' object has no attribute 'io'

# %%
import inspect
inspect.getmembers(skimage,inspect.ismodule)
# Out:
# [('_functools', <module 'functools' from '/usr/lib/python2.7/functools.pyc'>),
#  ('_imp', <module 'imp' (built-in)>),
#  ('_osp',
#   <module 'posixpath' from '/home/morten/.virtualenvs/Theano/lib/python2.7/posixpath.pyc'>),
#  ('_warnings',
#   <module 'warnings' from '/home/morten/.virtualenvs/Theano/lib/python2.7/warnings.pyc'>),
#  ('util',
#   <module 'skimage.util' from '/home/morten/.virtualenvs/Theano/local/lib/python2.7/site-packages/skimage/util/__init__.pyc'>)]

# %%
from skimage import io

# %%
camera = io.imread(os.path.join(skimage.data_dir, 'camera.png'))

# %%
plt.show(io.imshow(camera))
